# %% [markdown]
# <a href="https://colab.research.google.com/github/Nishthavan/Cognizant_Internship/blob/main/NLP_Pipeline_Assignment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Installing Important Libraries**

# %%
# Install spaCy 
# !pip install -U spacy  # (While working with neural_coref we should not update it) | Otherwise Update it
# Download the large Spacy English model
# !python3 -m spacy download en_core_web_lg
# Install textacy 
# !pip install -U textacy
# Out:
# Requirement already satisfied: spacy in /usr/local/lib/python3.7/dist-packages (3.2.4)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.8 in /usr/local/lib/python3.7/dist-packages (from spacy) (3.0.9)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from spacy) (57.4.0)
# Requirement already satisfied: wasabi<1.1.0,>=0.8.1 in /usr/local/lib/python3.7/dist-packages (from spacy) (0.9.1)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /usr/local/lib/python3.7/dist-packages (from spacy) (4.64.0)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<1.9.0,>=1.7.4 in /usr/local/lib/python3.7/dist-packages (from spacy) (1.8.2)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.7/dist-packages (from spacy) (1.0.6)
# Requirement already satisfied: numpy>=1.15.0 in /usr/local/lib/python3.7/dist-packages (from spacy) (1.21.5)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.7/dist-packages (from spacy) (2.11.3)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /usr/local/lib/python3.7/dist-packages (from spacy) (3.3.0)
# Requirement already satisfied: pathy>=0.3.5 in /usr/local/lib/python3.7/dist-packages (from spacy) (0.6.1)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /usr/local/lib/python3.7/dist-packages (from spacy) (2.0.7)
# Requirement already satisfied: blis<0.8.0,>=0.4.0 in /usr/local/lib/python3.7/dist-packages (from spacy) (0.4.1)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from spacy) (3.0.6)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /usr/local/lib/python3.7/dist-packages (from spacy) (2.23.0)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /usr/local/lib/python3.7/dist-packages (from spacy) (1.0.2)
# Requirement already satisfied: thinc<8.1.0,>=8.0.12 in /usr/local/lib/python3.7/dist-packages (from spacy) (8.0.15)
# Requirement already satisfied: click<8.1.0 in /usr/local/lib/python3.7/dist-packages (from spacy) (7.1.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.7/dist-packages (from spacy) (21.3)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from spacy) (2.0.6)
# Requirement already satisfied: typing-extensions<4.0.0.0,>=3.7.4 in /usr/local/lib/python3.7/dist-packages (from spacy) (3.10.0.2)
# Requirement already satisfied: typer<0.5.0,>=0.3.0 in /usr/local/lib/python3.7/dist-packages (from spacy) (0.4.1)
# Requirement already satisfied: srsly<3.0.0,>=2.4.1 in /usr/local/lib/python3.7/dist-packages (from spacy) (2.4.3)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from catalogue<2.1.0,>=2.0.6->spacy) (3.8.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging>=20.0->spacy) (3.0.8)
# Requirement already satisfied: smart-open<6.0.0,>=5.0.0 in /usr/local/lib/python3.7/dist-packages (from pathy>=0.3.5->spacy) (5.2.1)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->spacy) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->spacy) (1.25.11)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->spacy) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->spacy) (2021.10.8)
# Requirement already satisfied: MarkupSafe>=0.23 in /usr/local/lib/python3.7/dist-packages (from jinja2->spacy) (2.0.1)
# Collecting en-core-web-lg==3.2.0
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_lg-3.2.0/en_core_web_lg-3.2.0-py3-none-any.whl (777.4 MB)
#      |████████████████████████████████| 777.4 MB 5.4 kB/s
# Requirement already satisfied: spacy<3.3.0,>=3.2.0 in /usr/local/lib/python3.7/dist-packages (from en-core-web-lg==3.2.0) (3.2.4)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /usr/local/lib/python3.7/dist-packages (from spacy<3.3.0,>=3.2.0->en-core-web-lg==3.2.0) (2.23.0)
# Requirement already satisfied: wasabi<1.1.0,>=0.8.1 in /usr/local/lib/python3.7/dist-packages (from spacy<3.3.0,>=3.2.0->en-core-web-lg==3.2.0) (0.9.1)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /usr/local/lib/python3.7/dist-packages (from spacy<3.3.0,>=3.2.0->en-core-web-lg==3.2.0) (1.0.2)
# Requirement already satisfied: blis<0.8.0,>=0.4.0 in /usr/local/lib/python3.7/dist-packages (from spacy<3.3.0,>=3.2.0->en-core-web-lg==3.2.0) (0.4.1)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.8 in /usr/local/lib/python3.7/dist-packages (from spacy<3.3.0,>=3.2.0->en-core-web-lg==3.2.0) (3.0.9)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.7/dist-packages (from spacy<3.3.0,>=3.2.0->en-core-web-lg==3.2.0) (2.11.3)
# Requirement already satisfied: typing-extensions<4.0.0.0,>=3.7.4 in /usr/local/lib/python3.7/dist-packages (from spacy<3.3.0,>=3.2.0->en-core-web-lg==3.2.0) (3.10.0.2)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from spacy<3.3.0,>=3.2.0->en-core-web-lg==3.2.0) (2.0.6)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<1.9.0,>=1.7.4 in /usr/local/lib/python3.7/dist-packages (from spacy<3.3.0,>=3.2.0->en-core-web-lg==3.2.0) (1.8.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.7/dist-packages (from spacy<3.3.0,>=3.2.0->en-core-web-lg==3.2.0) (21.3)
# Requirement already satisfied: pathy>=0.3.5 in /usr/local/lib/python3.7/dist-packages (from spacy<3.3.0,>=3.2.0->en-core-web-lg==3.2.0) (0.6.1)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /usr/local/lib/python3.7/dist-packages (from spacy<3.3.0,>=3.2.0->en-core-web-lg==3.2.0) (3.3.0)
# Requirement already satisfied: typer<0.5.0,>=0.3.0 in /usr/local/lib/python3.7/dist-packages (from spacy<3.3.0,>=3.2.0->en-core-web-lg==3.2.0) (0.4.1)
# Requirement already satisfied: numpy>=1.15.0 in /usr/local/lib/python3.7/dist-packages (from spacy<3.3.0,>=3.2.0->en-core-web-lg==3.2.0) (1.21.5)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from spacy<3.3.0,>=3.2.0->en-core-web-lg==3.2.0) (3.0.6)
# Requirement already satisfied: srsly<3.0.0,>=2.4.1 in /usr/local/lib/python3.7/dist-packages (from spacy<3.3.0,>=3.2.0->en-core-web-lg==3.2.0) (2.4.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from spacy<3.3.0,>=3.2.0->en-core-web-lg==3.2.0) (57.4.0)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.7/dist-packages (from spacy<3.3.0,>=3.2.0->en-core-web-lg==3.2.0) (1.0.6)
# Requirement already satisfied: thinc<8.1.0,>=8.0.12 in /usr/local/lib/python3.7/dist-packages (from spacy<3.3.0,>=3.2.0->en-core-web-lg==3.2.0) (8.0.15)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /usr/local/lib/python3.7/dist-packages (from spacy<3.3.0,>=3.2.0->en-core-web-lg==3.2.0) (4.64.0)
# Requirement already satisfied: click<8.1.0 in /usr/local/lib/python3.7/dist-packages (from spacy<3.3.0,>=3.2.0->en-core-web-lg==3.2.0) (7.1.2)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /usr/local/lib/python3.7/dist-packages (from spacy<3.3.0,>=3.2.0->en-core-web-lg==3.2.0) (2.0.7)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from catalogue<2.1.0,>=2.0.6->spacy<3.3.0,>=3.2.0->en-core-web-lg==3.2.0) (3.8.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging>=20.0->spacy<3.3.0,>=3.2.0->en-core-web-lg==3.2.0) (3.0.8)
# Requirement already satisfied: smart-open<6.0.0,>=5.0.0 in /usr/local/lib/python3.7/dist-packages (from pathy>=0.3.5->spacy<3.3.0,>=3.2.0->en-core-web-lg==3.2.0) (5.2.1)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.3.0,>=3.2.0->en-core-web-lg==3.2.0) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.3.0,>=3.2.0->en-core-web-lg==3.2.0) (2021.10.8)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.3.0,>=3.2.0->en-core-web-lg==3.2.0) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.3.0,>=3.2.0->en-core-web-lg==3.2.0) (1.25.11)
# Requirement already satisfied: MarkupSafe>=0.23 in /usr/local/lib/python3.7/dist-packages (from jinja2->spacy<3.3.0,>=3.2.0->en-core-web-lg==3.2.0) (2.0.1)
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_lg')
# Requirement already satisfied: textacy in /usr/local/lib/python3.7/dist-packages (0.11.0)
# Requirement already satisfied: tqdm>=4.19.6 in /usr/local/lib/python3.7/dist-packages (from textacy) (4.64.0)
# Requirement already satisfied: scipy>=0.17.0 in /usr/local/lib/python3.7/dist-packages (from textacy) (1.4.1)
# Requirement already satisfied: requests>=2.10.0 in /usr/local/lib/python3.7/dist-packages (from textacy) (2.23.0)
# Requirement already satisfied: scikit-learn>=0.19.0 in /usr/local/lib/python3.7/dist-packages (from textacy) (1.0.2)
# Requirement already satisfied: spacy>=3.0.0 in /usr/local/lib/python3.7/dist-packages (from textacy) (3.2.4)
# Requirement already satisfied: pyphen>=0.10.0 in /usr/local/lib/python3.7/dist-packages (from textacy) (0.12.0)
# Requirement already satisfied: networkx>=2.0 in /usr/local/lib/python3.7/dist-packages (from textacy) (2.6.3)
# Requirement already satisfied: cytoolz>=0.10.1 in /usr/local/lib/python3.7/dist-packages (from textacy) (0.11.2)
# Requirement already satisfied: numpy>=1.17.0 in /usr/local/lib/python3.7/dist-packages (from textacy) (1.21.5)
# Requirement already satisfied: joblib>=0.13.0 in /usr/local/lib/python3.7/dist-packages (from textacy) (1.1.0)
# Requirement already satisfied: cachetools>=4.0.0 in /usr/local/lib/python3.7/dist-packages (from textacy) (4.2.4)
# Requirement already satisfied: jellyfish>=0.8.0 in /usr/local/lib/python3.7/dist-packages (from textacy) (0.9.0)
# Requirement already satisfied: toolz>=0.8.0 in /usr/local/lib/python3.7/dist-packages (from cytoolz>=0.10.1->textacy) (0.11.2)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests>=2.10.0->textacy) (1.25.11)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests>=2.10.0->textacy) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests>=2.10.0->textacy) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests>=2.10.0->textacy) (2021.10.8)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from scikit-learn>=0.19.0->textacy) (3.1.0)
# Requirement already satisfied: wasabi<1.1.0,>=0.8.1 in /usr/local/lib/python3.7/dist-packages (from spacy>=3.0.0->textacy) (0.9.1)
# Requirement already satisfied: srsly<3.0.0,>=2.4.1 in /usr/local/lib/python3.7/dist-packages (from spacy>=3.0.0->textacy) (2.4.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from spacy>=3.0.0->textacy) (57.4.0)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /usr/local/lib/python3.7/dist-packages (from spacy>=3.0.0->textacy) (2.0.7)
# Requirement already satisfied: typing-extensions<4.0.0.0,>=3.7.4 in /usr/local/lib/python3.7/dist-packages (from spacy>=3.0.0->textacy) (3.10.0.2)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from spacy>=3.0.0->textacy) (2.0.6)
# Requirement already satisfied: thinc<8.1.0,>=8.0.12 in /usr/local/lib/python3.7/dist-packages (from spacy>=3.0.0->textacy) (8.0.15)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.7/dist-packages (from spacy>=3.0.0->textacy) (1.0.6)
# Requirement already satisfied: click<8.1.0 in /usr/local/lib/python3.7/dist-packages (from spacy>=3.0.0->textacy) (7.1.2)
# Requirement already satisfied: typer<0.5.0,>=0.3.0 in /usr/local/lib/python3.7/dist-packages (from spacy>=3.0.0->textacy) (0.4.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.7/dist-packages (from spacy>=3.0.0->textacy) (2.11.3)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from spacy>=3.0.0->textacy) (3.0.6)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.8 in /usr/local/lib/python3.7/dist-packages (from spacy>=3.0.0->textacy) (3.0.9)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<1.9.0,>=1.7.4 in /usr/local/lib/python3.7/dist-packages (from spacy>=3.0.0->textacy) (1.8.2)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /usr/local/lib/python3.7/dist-packages (from spacy>=3.0.0->textacy) (3.3.0)
# Requirement already satisfied: pathy>=0.3.5 in /usr/local/lib/python3.7/dist-packages (from spacy>=3.0.0->textacy) (0.6.1)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.7/dist-packages (from spacy>=3.0.0->textacy) (21.3)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /usr/local/lib/python3.7/dist-packages (from spacy>=3.0.0->textacy) (1.0.2)
# Requirement already satisfied: blis<0.8.0,>=0.4.0 in /usr/local/lib/python3.7/dist-packages (from spacy>=3.0.0->textacy) (0.4.1)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from catalogue<2.1.0,>=2.0.6->spacy>=3.0.0->textacy) (3.8.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging>=20.0->spacy>=3.0.0->textacy) (3.0.8)
# Requirement already satisfied: smart-open<6.0.0,>=5.0.0 in /usr/local/lib/python3.7/dist-packages (from pathy>=0.3.5->spacy>=3.0.0->textacy) (5.2.1)
# Requirement already satisfied: MarkupSafe>=0.23 in /usr/local/lib/python3.7/dist-packages (from jinja2->spacy>=3.0.0->textacy) (2.0.1)

# %% [markdown]
# # **Getting The Data & Loading The NLP Model**

# %%
import spacy
import textacy
# Loading the English NLP model
NLP = spacy.load('en_core_web_lg')
# Reading data from the file
File = open("Data.txt", "rt")
text = File.read()
print(text)
# Out:
# ﻿We created AlphaGo, a computer program that combines advanced search trees with deep neural networks. These neural networks take a description of the Go board as an input and process it through a number of different network layers containing millions of neuron-like connections. One neural network, the “policy network”, selects the next move to play. The other neural network, the “value network”, predicts the winner of the game. We introduced AlphaGo to numerous amateur games to help it develop an understanding of the reasonable human play. Then we had it play against different versions of itself thousands of times, each time learning from its mistakes. Over time, AlphaGo improved and became increasingly stronger and better at learning and decision-making. This process is known as reinforcement learning. AlphaGo went on to defeat Go world champions in different global arenas and arguably became the greatest Go player of all time.

# %%
# Parsing the text with Spacy
final_doc = NLP(text)

# %% [markdown]
# # **1. Sentence Segmentation**

# %%
sentences = text.split(".")
for sentence in sentences:
  print(sentence)

print("-----------Different Method-------------")
print()
# We can also do this with help of parsed text. which is a better way
# Because it can work even if the data is not formatted cleanly

for sentence in final_doc.sents:
  print(sentence.text)
# Out:
# ﻿We created AlphaGo, a computer program that combines advanced search trees with deep neural networks
#  These neural networks take a description of the Go board as an input and process it through a number of different network layers containing millions of neuron-like connections
#  One neural network, the “policy network”, selects the next move to play
#  The other neural network, the “value network”, predicts the winner of the game
#  We introduced AlphaGo to numerous amateur games to help it develop an understanding of the reasonable human play
#  Then we had it play against different versions of itself thousands of times, each time learning from its mistakes
#  Over time, AlphaGo improved and became increasingly stronger and better at learning and decision-making
#  This process is known as reinforcement learning
#  AlphaGo went on to defeat Go world champions in different global arenas and arguably became the greatest Go player of all time
#
# -----------Different Method-------------
#
# ﻿We created AlphaGo, a computer program that combines advanced search trees with deep neural networks.
# These neural networks take a description of the Go board as an input and process it through a number of different network layers containing millions of neuron-like connections.
# One neural network, the “policy network”, selects the next move to play.
# The other neural network, the “value network”, predicts the winner of the game.
# We introduced AlphaGo to numerous amateur games to help it develop an understanding of the reasonable human play.
# Then we had it play against different versions of itself thousands of times, each time learning from its mistakes.
# Over time, AlphaGo improved and became increasingly stronger and better at learning and decision-making.
# This process is known as reinforcement learning.
# AlphaGo went on to defeat Go world champions in different global arenas and arguably became the greatest Go player of all time.

# %% [markdown]
# # **2. Tokenization**

# %%
tokens = [] 
for token in final_doc:
  tokens.append(token.text)
print(tokens)
print(len(tokens))
# Out:
# ['We', 'created', 'AlphaGo', ',', 'a', 'computer', 'program', 'that', 'combines', 'advanced', 'search', 'trees', 'with', 'deep', 'neural', 'networks', '.', 'These', 'neural', 'networks', 'take', 'a', 'description', 'of', 'the', 'Go', 'board', 'as', 'an', 'input', 'and', 'process', 'it', 'through', 'a', 'number', 'of', 'different', 'network', 'layers', 'containing', 'millions', 'of', 'neuron', '-', 'like', 'connections', '.', 'One', 'neural', 'network', ',', 'the', '“', 'policy', 'network', '”', ',', 'selects', 'the', 'next', 'move', 'to', 'play', '.', 'The', 'other', 'neural', 'network', ',', 'the', '“', 'value', 'network', '”', ',', 'predicts', 'the', 'winner', 'of', 'the', 'game', '.', 'We', 'introduced', 'AlphaGo', 'to', 'numerous', 'amateur', 'games', 'to', 'help', 'it', 'develop', 'an', 'understanding', 'of', 'the', 'reasonable', 'human', 'play', '.', 'Then', 'we', 'had', 'it', 'play', 'against', 'different', 'versions', 'of', 'itself', 'thousands', 'of', 'times', ',', 'each', 'time', 'learning', 'from', 'its', 'mistakes', '.', 'Over', 'time', ',', 'AlphaGo', 'improved', 'and', 'became', 'increasingly', 'stronger', 'and', 'better', 'at', 'learning', 'and', 'decision', '-', 'making', '.', 'This', 'process', 'is', 'known', 'as', 'reinforcement', 'learning', '.', 'AlphaGo', 'went', 'on', 'to', 'defeat', 'Go', 'world', 'champions', 'in', 'different', 'global', 'arenas', 'and', 'arguably', 'became', 'the', 'greatest', 'Go', 'player', 'of', 'all', 'time', '.']
# 172

# %% [markdown]
# # **3. Part of Speech**

# %%
from prettytable import PrettyTable # Using PrettyTable to create Table
Table = PrettyTable(["Word","TAG","Meaning of TAG","POS","Meaning of POS"])
for token in final_doc:
  Table.add_row([token.text, token.tag_, spacy.explain(token.tag_),token.pos_ ,spacy.explain(token.pos_)]) # Adding data to table
print(Table)
# Out:
# +---------------+------+----------------------------------------------------+-------+--------------------------+
# |      Word     | TAG  |                   Meaning of TAG                   |  POS  |      Meaning of POS      |
# +---------------+------+----------------------------------------------------+-------+--------------------------+
# |      ﻿We      |  RB  |                       adverb                       |  ADV  |          adverb          |
# |    created    | VBN  |               verb, past participle                |  VERB |           verb           |
# |    AlphaGo    | NNP  |               noun, proper singular                | PROPN |       proper noun        |
# |       ,       |  ,   |              punctuation mark, comma               | PUNCT |       punctuation        |
# |       a       |  DT  |                     determiner                     |  DET  |        determiner        |
# |    computer   |  NN  |               noun, singular or mass               |  NOUN |           noun           |
# |    program    |  NN  |               noun, singular or mass               |  NOUN |           noun           |
# |      that     | WDT  |                   wh-determiner                    |  PRON |         pronoun          |
# |    combines   | VBZ  |         verb, 3rd person singular present          |  VERB |           verb           |
# |    advanced   |  JJ  | adjective (English), other noun-modifier (Chinese) |  ADJ  |        adjective         |
# |     search    |  NN  |               noun, singular or mass               |  NOUN |           noun           |
# |     trees     | NNS  |                    noun, plural                    |  NOUN |           noun           |
# |      with     |  IN  |     conjunction, subordinating or preposition      |  ADP  |        adposition        |
# |      deep     |  JJ  | adjective (English), other noun-modifier (Chinese) |  ADJ  |        adjective         |
# |     neural    |  JJ  | adjective (English), other noun-modifier (Chinese) |  ADJ  |        adjective         |
# |    networks   | NNS  |                    noun, plural                    |  NOUN |           noun           |
# |       .       |  .   |         punctuation mark, sentence closer          | PUNCT |       punctuation        |
# |     These     |  DT  |                     determiner                     |  DET  |        determiner        |
# |     neural    |  JJ  | adjective (English), other noun-modifier (Chinese) |  ADJ  |        adjective         |
# |    networks   | NNS  |                    noun, plural                    |  NOUN |           noun           |
# |      take     | VBP  |       verb, non-3rd person singular present        |  VERB |           verb           |
# |       a       |  DT  |                     determiner                     |  DET  |        determiner        |
# |  description  |  NN  |               noun, singular or mass               |  NOUN |           noun           |
# |       of      |  IN  |     conjunction, subordinating or preposition      |  ADP  |        adposition        |
# |      the      |  DT  |                     determiner                     |  DET  |        determiner        |
# |       Go      | NNP  |               noun, proper singular                | PROPN |       proper noun        |
# |     board     |  NN  |               noun, singular or mass               |  NOUN |           noun           |
# |       as      |  IN  |     conjunction, subordinating or preposition      |  ADP  |        adposition        |
# |       an      |  DT  |                     determiner                     |  DET  |        determiner        |
# |     input     |  NN  |               noun, singular or mass               |  NOUN |           noun           |
# |      and      |  CC  |             conjunction, coordinating              | CCONJ | coordinating conjunction |
# |    process    |  VB  |                  verb, base form                   |  VERB |           verb           |
# |       it      | PRP  |                 pronoun, personal                  |  PRON |         pronoun          |
# |    through    |  IN  |     conjunction, subordinating or preposition      |  ADP  |        adposition        |
# |       a       |  DT  |                     determiner                     |  DET  |        determiner        |
# |     number    |  NN  |               noun, singular or mass               |  NOUN |           noun           |
# |       of      |  IN  |     conjunction, subordinating or preposition      |  ADP  |        adposition        |
# |   different   |  JJ  | adjective (English), other noun-modifier (Chinese) |  ADJ  |        adjective         |
# |    network    |  NN  |               noun, singular or mass               |  NOUN |           noun           |
# |     layers    | NNS  |                    noun, plural                    |  NOUN |           noun           |
# |   containing  | VBG  |         verb, gerund or present participle         |  VERB |           verb           |
# |    millions   | NNS  |                    noun, plural                    |  NOUN |           noun           |
# |       of      |  IN  |     conjunction, subordinating or preposition      |  ADP  |        adposition        |
# |     neuron    |  NN  |               noun, singular or mass               |  NOUN |           noun           |
# |       -       | HYPH |              punctuation mark, hyphen              | PUNCT |       punctuation        |
# |      like     |  JJ  | adjective (English), other noun-modifier (Chinese) |  ADJ  |        adjective         |
# |  connections  | NNS  |                    noun, plural                    |  NOUN |           noun           |
# |       .       |  .   |         punctuation mark, sentence closer          | PUNCT |       punctuation        |
# |      One      |  CD  |                  cardinal number                   |  NUM  |         numeral          |
# |     neural    |  JJ  | adjective (English), other noun-modifier (Chinese) |  ADJ  |        adjective         |
# |    network    |  NN  |               noun, singular or mass               |  NOUN |           noun           |
# |       ,       |  ,   |              punctuation mark, comma               | PUNCT |       punctuation        |
# |      the      |  DT  |                     determiner                     |  DET  |        determiner        |
# |       “       |  ``  |               opening quotation mark               | PUNCT |       punctuation        |
# |     policy    |  NN  |               noun, singular or mass               |  NOUN |           noun           |
# |    network    |  NN  |               noun, singular or mass               |  NOUN |           noun           |
# |       ”       |  ''  |               closing quotation mark               | PUNCT |       punctuation        |
# |       ,       |  ,   |              punctuation mark, comma               | PUNCT |       punctuation        |
# |    selects    | VBZ  |         verb, 3rd person singular present          |  VERB |           verb           |
# |      the      |  DT  |                     determiner                     |  DET  |        determiner        |
# |      next     |  JJ  | adjective (English), other noun-modifier (Chinese) |  ADJ  |        adjective         |
# |      move     |  NN  |               noun, singular or mass               |  NOUN |           noun           |
# |       to      |  TO  |                  infinitival "to"                  |  PART |         particle         |
# |      play     |  VB  |                  verb, base form                   |  VERB |           verb           |
# |       .       |  .   |         punctuation mark, sentence closer          | PUNCT |       punctuation        |
# |      The      |  DT  |                     determiner                     |  DET  |        determiner        |
# |     other     |  JJ  | adjective (English), other noun-modifier (Chinese) |  ADJ  |        adjective         |
# |     neural    |  JJ  | adjective (English), other noun-modifier (Chinese) |  ADJ  |        adjective         |
# |    network    |  NN  |               noun, singular or mass               |  NOUN |           noun           |
# |       ,       |  ,   |              punctuation mark, comma               | PUNCT |       punctuation        |
# |      the      |  DT  |                     determiner                     |  DET  |        determiner        |
# |       “       |  ``  |               opening quotation mark               | PUNCT |       punctuation        |
# |     value     |  NN  |               noun, singular or mass               |  NOUN |           noun           |
# |    network    |  NN  |               noun, singular or mass               |  NOUN |           noun           |
# |       ”       |  ''  |               closing quotation mark               | PUNCT |       punctuation        |
# |       ,       |  ,   |              punctuation mark, comma               | PUNCT |       punctuation        |
# |    predicts   | VBZ  |         verb, 3rd person singular present          |  VERB |           verb           |
# |      the      |  DT  |                     determiner                     |  DET  |        determiner        |
# |     winner    |  NN  |               noun, singular or mass               |  NOUN |           noun           |
# |       of      |  IN  |     conjunction, subordinating or preposition      |  ADP  |        adposition        |
# |      the      |  DT  |                     determiner                     |  DET  |        determiner        |
# |      game     |  NN  |               noun, singular or mass               |  NOUN |           noun           |
# |       .       |  .   |         punctuation mark, sentence closer          | PUNCT |       punctuation        |
# |       We      | PRP  |                 pronoun, personal                  |  PRON |         pronoun          |
# |   introduced  | VBD  |                  verb, past tense                  |  VERB |           verb           |
# |    AlphaGo    |  NN  |               noun, singular or mass               |  NOUN |           noun           |
# |       to      |  IN  |     conjunction, subordinating or preposition      |  ADP  |        adposition        |
# |    numerous   |  JJ  | adjective (English), other noun-modifier (Chinese) |  ADJ  |        adjective         |
# |    amateur    |  JJ  | adjective (English), other noun-modifier (Chinese) |  ADJ  |        adjective         |
# |     games     | NNS  |                    noun, plural                    |  NOUN |           noun           |
# |       to      |  TO  |                  infinitival "to"                  |  PART |         particle         |
# |      help     |  VB  |                  verb, base form                   |  VERB |           verb           |
# |       it      | PRP  |                 pronoun, personal                  |  PRON |         pronoun          |
# |    develop    |  VB  |                  verb, base form                   |  VERB |           verb           |
# |       an      |  DT  |                     determiner                     |  DET  |        determiner        |
# | understanding |  NN  |               noun, singular or mass               |  NOUN |           noun           |
# |       of      |  IN  |     conjunction, subordinating or preposition      |  ADP  |        adposition        |
# |      the      |  DT  |                     determiner                     |  DET  |        determiner        |
# |   reasonable  |  JJ  | adjective (English), other noun-modifier (Chinese) |  ADJ  |        adjective         |
# |     human     |  JJ  | adjective (English), other noun-modifier (Chinese) |  ADJ  |        adjective         |
# |      play     |  NN  |               noun, singular or mass               |  NOUN |           noun           |
# |       .       |  .   |         punctuation mark, sentence closer          | PUNCT |       punctuation        |
# |      Then     |  RB  |                       adverb                       |  ADV  |          adverb          |
# |       we      | PRP  |                 pronoun, personal                  |  PRON |         pronoun          |
# |      had      | VBD  |                  verb, past tense                  |  VERB |           verb           |
# |       it      | PRP  |                 pronoun, personal                  |  PRON |         pronoun          |
# |      play     |  VB  |                  verb, base form                   |  VERB |           verb           |
# |    against    |  IN  |     conjunction, subordinating or preposition      |  ADP  |        adposition        |
# |   different   |  JJ  | adjective (English), other noun-modifier (Chinese) |  ADJ  |        adjective         |
# |    versions   | NNS  |                    noun, plural                    |  NOUN |           noun           |
# |       of      |  IN  |     conjunction, subordinating or preposition      |  ADP  |        adposition        |
# |     itself    | PRP  |                 pronoun, personal                  |  PRON |         pronoun          |
# |   thousands   | NNS  |                    noun, plural                    |  NOUN |           noun           |
# |       of      |  IN  |     conjunction, subordinating or preposition      |  ADP  |        adposition        |
# |     times     | NNS  |                    noun, plural                    |  NOUN |           noun           |
# |       ,       |  ,   |              punctuation mark, comma               | PUNCT |       punctuation        |
# |      each     |  DT  |                     determiner                     |  DET  |        determiner        |
# |      time     |  NN  |               noun, singular or mass               |  NOUN |           noun           |
# |    learning   | VBG  |         verb, gerund or present participle         |  VERB |           verb           |
# |      from     |  IN  |     conjunction, subordinating or preposition      |  ADP  |        adposition        |
# |      its      | PRP$ |                pronoun, possessive                 |  PRON |         pronoun          |
# |    mistakes   | NNS  |                    noun, plural                    |  NOUN |           noun           |
# |       .       |  .   |         punctuation mark, sentence closer          | PUNCT |       punctuation        |
# |      Over     |  IN  |     conjunction, subordinating or preposition      |  ADP  |        adposition        |
# |      time     |  NN  |               noun, singular or mass               |  NOUN |           noun           |
# |       ,       |  ,   |              punctuation mark, comma               | PUNCT |       punctuation        |
# |    AlphaGo    |  NN  |               noun, singular or mass               |  NOUN |           noun           |
# |    improved   | VBD  |                  verb, past tense                  |  VERB |           verb           |
# |      and      |  CC  |             conjunction, coordinating              | CCONJ | coordinating conjunction |
# |     became    | VBD  |                  verb, past tense                  |  VERB |           verb           |
# |  increasingly |  RB  |                       adverb                       |  ADV  |          adverb          |
# |    stronger   | JJR  |               adjective, comparative               |  ADJ  |        adjective         |
# |      and      |  CC  |             conjunction, coordinating              | CCONJ | coordinating conjunction |
# |     better    | JJR  |               adjective, comparative               |  ADJ  |        adjective         |
# |       at      |  IN  |     conjunction, subordinating or preposition      |  ADP  |        adposition        |
# |    learning   |  NN  |               noun, singular or mass               |  NOUN |           noun           |
# |      and      |  CC  |             conjunction, coordinating              | CCONJ | coordinating conjunction |
# |    decision   |  NN  |               noun, singular or mass               |  NOUN |           noun           |
# |       -       | HYPH |              punctuation mark, hyphen              | PUNCT |       punctuation        |
# |     making    |  NN  |               noun, singular or mass               |  NOUN |           noun           |
# |       .       |  .   |         punctuation mark, sentence closer          | PUNCT |       punctuation        |
# |      This     |  DT  |                     determiner                     |  DET  |        determiner        |
# |    process    |  NN  |               noun, singular or mass               |  NOUN |           noun           |
# |       is      | VBZ  |         verb, 3rd person singular present          |  AUX  |        auxiliary         |
# |     known     | VBN  |               verb, past participle                |  VERB |           verb           |
# |       as      |  IN  |     conjunction, subordinating or preposition      |  ADP  |        adposition        |
# | reinforcement |  NN  |               noun, singular or mass               |  NOUN |           noun           |
# |    learning   |  NN  |               noun, singular or mass               |  NOUN |           noun           |
# |       .       |  .   |         punctuation mark, sentence closer          | PUNCT |       punctuation        |
# |    AlphaGo    | NNP  |               noun, proper singular                | PROPN |       proper noun        |
# |      went     | VBD  |                  verb, past tense                  |  VERB |           verb           |
# |       on      |  RP  |                  adverb, particle                  |  ADP  |        adposition        |
# |       to      |  TO  |                  infinitival "to"                  |  PART |         particle         |
# |     defeat    |  VB  |                  verb, base form                   |  VERB |           verb           |
# |       Go      |  VB  |                  verb, base form                   |  VERB |           verb           |
# |     world     |  NN  |               noun, singular or mass               |  NOUN |           noun           |
# |   champions   | NNS  |                    noun, plural                    |  NOUN |           noun           |
# |       in      |  IN  |     conjunction, subordinating or preposition      |  ADP  |        adposition        |
# |   different   |  JJ  | adjective (English), other noun-modifier (Chinese) |  ADJ  |        adjective         |
# |     global    |  JJ  | adjective (English), other noun-modifier (Chinese) |  ADJ  |        adjective         |
# |     arenas    | NNS  |                    noun, plural                    |  NOUN |           noun           |
# |      and      |  CC  |             conjunction, coordinating              | CCONJ | coordinating conjunction |
# |    arguably   |  RB  |                       adverb                       |  ADV  |          adverb          |
# |     became    | VBD  |                  verb, past tense                  |  VERB |           verb           |
# |      the      |  DT  |                     determiner                     |  DET  |        determiner        |
# |    greatest   | JJS  |               adjective, superlative               |  ADJ  |        adjective         |
# |       Go      | NNP  |               noun, proper singular                | PROPN |       proper noun        |
# |     player    |  NN  |               noun, singular or mass               |  NOUN |           noun           |
# |       of      |  IN  |     conjunction, subordinating or preposition      |  ADP  |        adposition        |
# |      all      |  DT  |                     determiner                     |  DET  |        determiner        |
# |      time     |  NN  |               noun, singular or mass               |  NOUN |           noun           |
# |       .       |  .   |         punctuation mark, sentence closer          | PUNCT |       punctuation        |
# +---------------+------+----------------------------------------------------+-------+--------------------------+

# %% [markdown]
# # **4. Text Lemmatization**

# %%
# Figuring out the most basic form or lemma of each word.
Table2 = PrettyTable(["Word", "Lemma (int)", "Lemma (str)"])
for token in final_doc:
  Table2.add_row([token.text, token.lemma ,token.lemma_])
print(Table2)
# Out:
# +---------------+----------------------+---------------+
# |      Word     |     Lemma (int)      |  Lemma (str)  |
# +---------------+----------------------+---------------+
# |      ﻿We      | 10911418286934844680 |      ﻿we      |
# |    created    | 10217138629343254602 |     create    |
# |    AlphaGo    | 6073627545995165565  |    AlphaGo    |
# |       ,       | 2593208677638477497  |       ,       |
# |       a       | 11901859001352538922 |       a       |
# |    computer   | 4912942957612137283  |    computer   |
# |    program    | 17812688126189747487 |    program    |
# |      that     | 4380130941430378203  |      that     |
# |    combines   | 4438640794806048232  |    combine    |
# |    advanced   | 3943929226210916060  |    advanced   |
# |     search    |  295895373269394349  |     search    |
# |     trees     | 5236966400857015965  |      tree     |
# |      with     | 12510949447758279278 |      with     |
# |      deep     | 12691978708603459222 |      deep     |
# |     neural    | 1527895112069854733  |     neural    |
# |    networks   | 2515988597143367740  |    network    |
# |       .       | 12646065887601541794 |       .       |
# |     These     | 6459564349623679250  |     these     |
# |     neural    | 1527895112069854733  |     neural    |
# |    networks   | 2515988597143367740  |    network    |
# |      take     | 6789454535283781228  |      take     |
# |       a       | 11901859001352538922 |       a       |
# |  description  | 15699362302781265145 |  description  |
# |       of      |  886050111519832510  |       of      |
# |      the      | 7425985699627899538  |      the      |
# |       Go      | 5927671249132274586  |       Go      |
# |     board     | 14899812206273857344 |     board     |
# |       as      | 7437575085468336610  |       as      |
# |       an      | 15099054000809333061 |       an      |
# |     input     | 16509431157672309370 |     input     |
# |      and      | 2283656566040971221  |      and      |
# |    process    | 1020421249059553464  |    process    |
# |       it      | 10239237003504588839 |       it      |
# |    through    | 18216413589307435838 |    through    |
# |       a       | 11901859001352538922 |       a       |
# |     number    |         432          |     number    |
# |       of      |  886050111519832510  |       of      |
# |   different   | 17379251038783395147 |   different   |
# |    network    | 2515988597143367740  |    network    |
# |     layers    | 7486875045419418034  |     layer     |
# |   containing  | 9364007743113479444  |    contain    |
# |    millions   | 17365054503653917826 |    million    |
# |       of      |  886050111519832510  |       of      |
# |     neuron    | 10452704660894501306 |     neuron    |
# |       -       | 9153284864653046197  |       -       |
# |      like     | 18194338103975822726 |      like     |
# |  connections  | 14753437861310164020 |   connection  |
# |       .       | 12646065887601541794 |       .       |
# |      One      | 17454115351911680600 |      one      |
# |     neural    | 1527895112069854733  |     neural    |
# |    network    | 2515988597143367740  |    network    |
# |       ,       | 2593208677638477497  |       ,       |
# |      the      | 7425985699627899538  |      the      |
# |       “       | 15884554869126768810 |       "       |
# |     policy    | 1913136496811477923  |     policy    |
# |    network    | 2515988597143367740  |    network    |
# |       ”       | 15884554869126768810 |       "       |
# |       ,       | 2593208677638477497  |       ,       |
# |    selects    | 16380042908389975667 |     select    |
# |      the      | 7425985699627899538  |      the      |
# |      next     | 5589923990388768802  |      next     |
# |      move     | 13534686644065735227 |      move     |
# |       to      | 3791531372978436496  |       to      |
# |      play     | 8228585124152053988  |      play     |
# |       .       | 12646065887601541794 |       .       |
# |      The      | 7425985699627899538  |      the      |
# |     other     | 1176656782636220709  |     other     |
# |     neural    | 1527895112069854733  |     neural    |
# |    network    | 2515988597143367740  |    network    |
# |       ,       | 2593208677638477497  |       ,       |
# |      the      | 7425985699627899538  |      the      |
# |       “       | 15884554869126768810 |       "       |
# |     value     | 1345584765475359109  |     value     |
# |    network    | 2515988597143367740  |    network    |
# |       ”       | 15884554869126768810 |       "       |
# |       ,       | 2593208677638477497  |       ,       |
# |    predicts   | 7338873450149926214  |    predict    |
# |      the      | 7425985699627899538  |      the      |
# |     winner    | 1107591818652143627  |     winner    |
# |       of      |  886050111519832510  |       of      |
# |      the      | 7425985699627899538  |      the      |
# |      game     | 6371478730979445275  |      game     |
# |       .       | 12646065887601541794 |       .       |
# |       We      | 16064069575701507746 |       we      |
# |   introduced  | 9507357926607400307  |   introduce   |
# |    AlphaGo    |  273553719939672932  |    alphago    |
# |       to      | 3791531372978436496  |       to      |
# |    numerous   | 9257680907642490936  |    numerous   |
# |    amateur    | 17426642507396193391 |    amateur    |
# |     games     | 6371478730979445275  |      game     |
# |       to      | 3791531372978436496  |       to      |
# |      help     | 17461235395181654430 |      help     |
# |       it      | 10239237003504588839 |       it      |
# |    develop    | 16473443321107972938 |    develop    |
# |       an      | 15099054000809333061 |       an      |
# | understanding | 1392792401359955612  | understanding |
# |       of      |  886050111519832510  |       of      |
# |      the      | 7425985699627899538  |      the      |
# |   reasonable  | 16093343421169014319 |   reasonable  |
# |     human     | 5674190450704392893  |     human     |
# |      play     | 8228585124152053988  |      play     |
# |       .       | 12646065887601541794 |       .       |
# |      Then     | 2630753287402592467  |      then     |
# |       we      | 16064069575701507746 |       we      |
# |      had      | 14692702688101715474 |      have     |
# |       it      | 10239237003504588839 |       it      |
# |      play     | 8228585124152053988  |      play     |
# |    against    | 16640565335581469180 |    against    |
# |   different   | 17379251038783395147 |   different   |
# |    versions   | 2639073426372099914  |    version    |
# |       of      |  886050111519832510  |       of      |
# |     itself    | 12490679957485934169 |     itself    |
# |   thousands   | 2848708369715101064  |    thousand   |
# |       of      |  886050111519832510  |       of      |
# |     times     | 8885804376230376864  |      time     |
# |       ,       | 2593208677638477497  |       ,       |
# |      each     | 5379624210385286023  |      each     |
# |      time     | 8885804376230376864  |      time     |
# |    learning   | 9664905639869093544  |     learn     |
# |      from     | 7831658034963690409  |      from     |
# |      its      | 12513610393978129441 |      its      |
# |    mistakes   | 13445433781761108248 |    mistake    |
# |       .       | 12646065887601541794 |       .       |
# |      Over     | 5456543204961066030  |      over     |
# |      time     | 8885804376230376864  |      time     |
# |       ,       | 2593208677638477497  |       ,       |
# |    AlphaGo    |  273553719939672932  |    alphago    |
# |    improved   | 4687493659934148016  |    improve    |
# |      and      | 2283656566040971221  |      and      |
# |     became    | 12558846041070486771 |     become    |
# |  increasingly | 2326915202511957355  |  increasingly |
# |    stronger   | 12618292361406372890 |     strong    |
# |      and      | 2283656566040971221  |      and      |
# |     better    | 4525988469032889948  |      well     |
# |       at      | 11667289587015813222 |       at      |
# |    learning   | 7342778914265824300  |    learning   |
# |      and      | 2283656566040971221  |      and      |
# |    decision   | 5364348271814505298  |    decision   |
# |       -       | 9153284864653046197  |       -       |
# |     making    |  200141916689428108  |     making    |
# |       .       | 12646065887601541794 |       .       |
# |      This     | 1995909169258310477  |      this     |
# |    process    | 1020421249059553464  |    process    |
# |       is      | 10382539506755952630 |       be      |
# |     known     | 7743033266031195906  |      know     |
# |       as      | 7437575085468336610  |       as      |
# | reinforcement | 9010960456179905795  | reinforcement |
# |    learning   | 7342778914265824300  |    learning   |
# |       .       | 12646065887601541794 |       .       |
# |    AlphaGo    | 6073627545995165565  |    AlphaGo    |
# |      went     | 8004577259940138793  |       go      |
# |       on      | 5640369432778651323  |       on      |
# |       to      | 3791531372978436496  |       to      |
# |     defeat    | 14973525170827174687 |     defeat    |
# |       Go      | 8004577259940138793  |       go      |
# |     world     | 1703489418272052182  |     world     |
# |   champions   | 11628189761263483281 |    champion   |
# |       in      | 3002984154512732771  |       in      |
# |   different   | 17379251038783395147 |   different   |
# |     global    | 17053192215331816304 |     global    |
# |     arenas    | 6943555830490817058  |     arena     |
# |      and      | 2283656566040971221  |      and      |
# |    arguably   | 9972869937855989774  |    arguably   |
# |     became    | 12558846041070486771 |     become    |
# |      the      | 7425985699627899538  |      the      |
# |    greatest   | 8881679497796027013  |     great     |
# |       Go      | 5927671249132274586  |       Go      |
# |     player    | 3885285634180617021  |     player    |
# |       of      |  886050111519832510  |       of      |
# |      all      | 13409319323822384369 |      all      |
# |      time     | 8885804376230376864  |      time     |
# |       .       | 12646065887601541794 |       .       |
# +---------------+----------------------+---------------+

# %% [markdown]
# # **5. Stop Words**

# %%
# Stop words creats Noise while doing statistics on text as they appear more frequently, So we may wanna filter them out
# We can identify stop words by checking it with hardcoded known list of stop words.... 
# And we can create a personalized list of stop words to check against according to problem at hand.

All_Stopwords = NLP.Defaults.stop_words
print(len(All_Stopwords))
print(All_Stopwords)

# We can add our own words to this list by:
# NLP.Defaults.stop_words.add("New_Stopword")

# We can remove words from this list by:
# NLP.Defaults.stop_words.remove("Stopword")

print()
print("-------------------------------")
print()

# Cleaning or removing stop words:
Tokens = []
Words = []
Stop_Words = []
for token in final_doc:
  if(token.is_stop == False): # Checking if this is not a stop word
    Tokens.append(token)
    Words.append(token.text)
  else:
    Stop_Words.append(token.text)

# After removing stop words
print((" ".join(Words)))
print(len(Words))

print()

print("Stop Words: ")
# All the stopp words removed
print(Stop_Words)
print(len(Stop_Words))

# 106 + 66 (Stop words) = 172 (total)
# Out:
# 326
# {'above', 'nine', 'never', 'between', 'becoming', 'call', 'everyone', 'whole', 'hereby', "'m", 'put', 'from', 'please', 'almost', 'why', 'beside', 'your', 'wherever', 'the', 'hereafter', 'where', 'somehow', 'any', 'give', 'becomes', 'been', 'too', 'around', 'is', 'have', 'does', 'must', 'thence', 'unless', 'after', 'against', 'than', 'mostly', 'on', 'under', 'six', 'herein', '‘d', 'therefore', 'across', 'seem', 'this', 'seems', 'its', 'by', 'he', 'made', 'below', 'sometime', 'how', 'hundred', 'sixty', 'back', 'herself', 'more', 'then', 'former', 'last', 'few', 'make', 'since', 'off', 'was', 'nevertheless', 'what', 'quite', 'themselves', 'four', 'into', 'least', 'his', 'keep', 'over', 'via', 'even', 'not', 'could', 'while', 'name', 'her', 'itself', 'sometimes', 'my', 'although', 'whither', 'very', 'at', 'otherwise', 'noone', '’ll', 'ourselves', 'perhaps', 'be', 'myself', 'several', 'whereas', 'forty', 'top', 'those', 'mine', 'thereupon', 'down', 'get', 'until', 'everything', 'become', 'whom', 'nowhere', 'always', 'see', 'because', 'indeed', 'onto', 'who', 'with', 'thus', 'often', 'own', 'thereafter', 'regarding', 'three', 'whose', 'before', 'amount', 'well', 'per', 'became', '‘re', '‘ve', 'or', 'go', 'twelve', 'behind', 'most', 'using', 'whether', 'afterwards', 'except', 'already', 'them', 'elsewhere', 'about', 'up', 'without', 'yourselves', 'for', 'now', 'as', 'can', 'much', 'seeming', 'no', 'twenty', 'anyhow', '‘s', 'if', 'nothing', 'among', 'one', 'used', 'him', 'may', 'himself', 'through', 'seemed', 'show', 'still', 'am', 'full', 'first', 'along', 'something', 'whenever', 'beforehand', 'enough', 'ours', 'each', 'somewhere', '’s', 'doing', 'whence', 'which', 'to', "n't", 'whereupon', 'again', 'therein', 'empty', 'anyway', 'that', 'such', 're', 'fifty', 'i', 'else', 'formerly', 'amongst', 'in', 'latter', 'yours', '’m', 'here', 'cannot', 'and', "'ll", 'beyond', 'towards', 'bottom', 'moreover', 'meanwhile', 'we', '’d', 'whereafter', 'neither', 'toward', 'also', 'there', 'two', 'me', 'five', 'of', '’ve', 'out', 'many', 'anything', 'has', 'besides', 'once', 'less', 'ten', 'everywhere', 'fifteen', 'take', 'throughout', 'others', 'third', '‘ll', 'it', '‘m', "'d", 'nor', 'ever', "'s", 'n’t', 'she', "'re", 'whatever', 'thereby', 'various', 'just', 'are', 'whoever', 'would', 'done', 'our', 'wherein', 'front', 'ca', 'side', 'someone', 'further', 'all', 'yourself', 'eight', 'being', 'none', 'other', 'did', 'upon', 'they', 'really', 'might', 'a', 'do', 'thru', 'rather', 'every', 'namely', 'serious', 'an', 'within', 'hers', 'latterly', 'part', 'but', 'together', 'next', 'yet', 'hence', 'anyone', 'either', 'due', 'move', 'will', 'nobody', 'when', 'hereupon', 'these', 'alone', 'anywhere', 'both', 'during', 'another', 'however', 'had', 'some', 'though', 'n‘t', 'eleven', "'ve", 'their', 'us', 'you', 'same', 'should', 'say', 'were', 'only', '’re', 'so', 'whereby'}
#
# -------------------------------
#
# ﻿We created AlphaGo , computer program combines advanced search trees deep neural networks . neural networks description board input process number different network layers containing millions neuron - like connections . neural network , “ policy network ” , selects play . neural network , “ value network ” , predicts winner game . introduced AlphaGo numerous amateur games help develop understanding reasonable human play . play different versions thousands times , time learning mistakes . time , AlphaGo improved increasingly stronger better learning decision - making . process known reinforcement learning . AlphaGo went defeat world champions different global arenas arguably greatest player time .
# 106
#
# Stop Words:
# ['a', 'that', 'with', 'These', 'take', 'a', 'of', 'the', 'Go', 'as', 'an', 'and', 'it', 'through', 'a', 'of', 'of', 'One', 'the', 'the', 'next', 'move', 'to', 'The', 'other', 'the', 'the', 'of', 'the', 'We', 'to', 'to', 'it', 'an', 'of', 'the', 'Then', 'we', 'had', 'it', 'against', 'of', 'itself', 'of', 'each', 'from', 'its', 'Over', 'and', 'became', 'and', 'at', 'and', 'This', 'is', 'as', 'on', 'to', 'Go', 'in', 'and', 'became', 'the', 'Go', 'of', 'all']
# 66

# %% [markdown]
# # **6. Dependency Parsing**

# %%
from spacy import displacy
displacy.render(final_doc, jupyter=True, options={'distance':90})
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="3606bd43114542aabea5539ea50a32a6-0" class="displacy" width="13550" height="542.0" direction="ltr" style="max-width: none; height: 542.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="452.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">﻿We</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">ADV</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="452.0">
#     <tspan class="displacy-word" fill="currentColor" x="140">created</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="140">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="452.0">
#     <tspan class="displacy-word" fill="currentColor" x="230">AlphaGo,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="230">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="452.0">
#     <tspan class="displacy-word" fill="currentColor" x="320">a</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="320">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="452.0">
#     <tspan class="displacy-word" fill="currentColor" x="410">computer</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="410">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="452.0">
#     <tspan class="displacy-word" fill="currentColor" x="500">program</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="500">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="452.0">
#     <tspan class="displacy-word" fill="currentColor" x="590">that</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="590">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="452.0">
#     <tspan class="displacy-word" fill="currentColor" x="680">combines</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="680">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="452.0">
#     <tspan class="displacy-word" fill="currentColor" x="770">advanced</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="770">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="452.0">
#     <tspan class="displacy-word" fill="currentColor" x="860">search</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="860">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="452.0">
#     <tspan class="displacy-word" fill="currentColor" x="950">trees</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="950">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="452.0">
#     <tspan class="displacy-word" fill="currentColor" x="1040">with</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1040">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="452.0">
#     <tspan class="displacy-word" fill="currentColor" x="1130">deep</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1130">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="452.0">
#     <tspan class="displacy-word" fill="currentColor" x="1220">neural</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1220">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="452.0">
#     <tspan class="displacy-word" fill="currentColor" x="1310">networks.</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1310">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="452.0">
#     <tspan class="displacy-word" fill="currentColor" x="1400">These</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1400">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="452.0">
#     <tspan class="displacy-word" fill="currentColor" x="1490">neural</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1490">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="452.0">
#     <tspan class="displacy-word" fill="currentColor" x="1580">networks</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1580">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="452.0">
#     <tspan class="displacy-word" fill="currentColor" x="1670">take</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1670">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="452.0">
#     <tspan class="displacy-word" fill="currentColor" x="1760">a</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1760">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="452.0">
#     <tspan class="displacy-word" fill="currentColor" x="1850">description</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1850">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="452.0">
#     <tspan class="displacy-word" fill="currentColor" x="1940">of</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1940">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="452.0">
#     <tspan class="displacy-word" fill="currentColor" x="2030">the</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2030">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="452.0">
#     <tspan class="displacy-word" fill="currentColor" x="2120">Go</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2120">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="452.0">
#     <tspan class="displacy-word" fill="currentColor" x="2210">board</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2210">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="452.0">
#     <tspan class="displacy-word" fill="currentColor" x="2300">as</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2300">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="452.0">
#     <tspan class="displacy-word" fill="currentColor" x="2390">an</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2390">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="452.0">
#     <tspan class="displacy-word" fill="currentColor" x="2480">input</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2480">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="452.0">
#     <tspan class="displacy-word" fill="currentColor" x="2570">and</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2570">CCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="452.0">
#     <tspan class="displacy-word" fill="currentColor" x="2660">process</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2660">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="452.0">
#     <tspan class="displacy-word" fill="currentColor" x="2750">it</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x=

# %% [markdown]
# # **7. Finding Noun Phrases**

# %%
NounChunks = textacy.extract.noun_chunks(final_doc, min_freq=3) # Number of times it occurs (min_freq)
NounChunks = map(str, NounChunks)
NounChunks = map(str.lower, NounChunks) # Converting them to lower case str
# Now make a set of these so that they only have unique values
for NounChunk in set(NounChunks):
  if len(NounChunk.split(" ")) > 0: # Print out any noun that is atleasy 1 word long......
    print(NounChunk)
# Out:
# it
# alphago

# %% [markdown]
# # **8. Named Entity Recognition**

# %%
Table3 = PrettyTable(["Entity", "Label", "Meaning of Label"])
for entity in final_doc.ents:
  Table3.add_row([entity.text, entity.label_ ,spacy.explain(entity.label_)])
print(Table3)
# Out:
# +-----------+----------+----------------------------------------------+
# |   Entity  |  Label   |               Meaning of Label               |
# +-----------+----------+----------------------------------------------+
# |  AlphaGo  |   ORG    |   Companies, agencies, institutions, etc.    |
# |  millions | CARDINAL | Numerals that do not fall under another type |
# |    One    | CARDINAL | Numerals that do not fall under another type |
# |  AlphaGo  |  PERSON  |         People, including fictional          |
# | thousands | CARDINAL | Numerals that do not fall under another type |
# |  AlphaGo  |  PERSON  |         People, including fictional          |
# |  AlphaGo  |  PERSON  |         People, including fictional          |
# +-----------+----------+----------------------------------------------+

# %% [markdown]
# # **9. Conference Resolution** *Used Spacy 2.3.7 in this section*

# %%
''' We need Neuralcoref for this which is not compatible with the 3.2.4 version of spacy so this (9th Step) is executed with 
spacy -version = 2.3.7 instead of 3.2.4, but all the other 8 steps till now have used 3.2.4 version of spacy. & After updating packages 
Don't forget to restart the runtime always. '''

# !git clone https://github.com/huggingface/neuralcoref.git
# %cd neuralcoref
# !pip install -r requirements.txt
# !pip install -e .

# %%
# !python -m spacy download en
# Out:
# Collecting en_core_web_sm==2.3.1
#   Using cached en_core_web_sm-2.3.1-py3-none-any.whl
# Requirement already satisfied: spacy<2.4.0,>=2.3.0 in /usr/local/lib/python3.7/dist-packages (from en_core_web_sm==2.3.1) (2.3.7)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from spacy<2.4.0,>=2.3.0->en_core_web_sm==2.3.1) (57.4.0)
# Requirement already satisfied: catalogue<1.1.0,>=0.0.7 in /usr/local/lib/python3.7/dist-packages (from spacy<2.4.0,>=2.3.0->en_core_web_sm==2.3.1) (1.0.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /usr/local/lib/python3.7/dist-packages (from spacy<2.4.0,>=2.3.0->en_core_web_sm==2.3.1) (4.64.0)
# Requirement already satisfied: wasabi<1.1.0,>=0.4.0 in /usr/local/lib/python3.7/dist-packages (from spacy<2.4.0,>=2.3.0->en_core_web_sm==2.3.1) (0.9.1)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.7/dist-packages (from spacy<2.4.0,>=2.3.0->en_core_web_sm==2.3.1) (1.0.6)
# Requirement already satisfied: thinc<7.5.0,>=7.4.1 in /usr/local/lib/python3.7/dist-packages (from spacy<2.4.0,>=2.3.0->en_core_web_sm==2.3.1) (7.4.5)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from spacy<2.4.0,>=2.3.0->en_core_web_sm==2.3.1) (3.0.6)
# Requirement already satisfied: numpy>=1.15.0 in /usr/local/lib/python3.7/dist-packages (from spacy<2.4.0,>=2.3.0->en_core_web_sm==2.3.1) (1.21.5)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /usr/local/lib/python3.7/dist-packages (from spacy<2.4.0,>=2.3.0->en_core_web_sm==2.3.1) (2.23.0)
# Requirement already satisfied: srsly<1.1.0,>=1.0.2 in /usr/local/lib/python3.7/dist-packages (from spacy<2.4.0,>=2.3.0->en_core_web_sm==2.3.1) (1.0.5)
# Requirement already satisfied: plac<1.2.0,>=0.9.6 in /usr/local/lib/python3.7/dist-packages (from spacy<2.4.0,>=2.3.0->en_core_web_sm==2.3.1) (1.1.3)
# Requirement already satisfied: blis<0.8.0,>=0.4.0 in /usr/local/lib/python3.7/dist-packages (from spacy<2.4.0,>=2.3.0->en_core_web_sm==2.3.1) (0.4.1)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from spacy<2.4.0,>=2.3.0->en_core_web_sm==2.3.1) (2.0.6)
# Requirement already satisfied: importlib-metadata>=0.20 in /usr/local/lib/python3.7/dist-packages (from catalogue<1.1.0,>=0.0.7->spacy<2.4.0,>=2.3.0->en_core_web_sm==2.3.1) (4.11.3)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata>=0.20->catalogue<1.1.0,>=0.0.7->spacy<2.4.0,>=2.3.0->en_core_web_sm==2.3.1) (3.8.0)
# Requirement already satisfied: typing-extensions>=3.6.4 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata>=0.20->catalogue<1.1.0,>=0.0.7->spacy<2.4.0,>=2.3.0->en_core_web_sm==2.3.1) (3.10.0.2)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->spacy<2.4.0,>=2.3.0->en_core_web_sm==2.3.1) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->spacy<2.4.0,>=2.3.0->en_core_web_sm==2.3.1) (2021.10.8)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->spacy<2.4.0,>=2.3.0->en_core_web_sm==2.3.1) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->spacy<2.4.0,>=2.3.0->en_core_web_sm==2.3.1) (1.25.11)
# ✔ Download and installation successful
# You can now load the model via spacy.load('en_core_web_sm')
# ✔ Linking successful
# /usr/local/lib/python3.7/dist-packages/en_core_web_sm -->
# /usr/local/lib/python3.7/dist-packages/spacy/data/en
# You can now load the model via spacy.load('en')

# %%
# !pip show neuralcoref
# Out:
# Name: neuralcoref
# Version: 4.0
# Summary: Coreference Resolution in spaCy with Neural Networks
# Home-page: https://github.com/huggingface/neuralcoref
# Author: Thomas Wolf
# Author-email: thomwolf@gmail.com
# License: MIT
# Location: /content/NeuralCoref/neuralcoref
# Requires: numpy, boto3, requests, spacy
# Required-by:

# %%
import neuralcoref
import spacy
NLP1 = spacy.load('en')
neuralcoref.add_to_pipe(NLP1)

File = open("Data.txt", "rt")
text = File.read()

final_doc_1 = NLP1(text)
print(len(final_doc_1))
# Out:
# 172

# %%
# Printing all the Mentions in the text:
for cluster in final_doc_1._.coref_clusters:
    print(cluster.mentions)
# Out:
# [deep neural networks, These neural networks]
# [an input, it]
# [The other neural network, the “value network”, We, we]
# [AlphaGo, it, it, itself, its, AlphaGo, AlphaGo]

# %%
# Printing pronouns & their references
for token in final_doc_1:
    if token.pos_ == 'PRON' and token._.in_coref:
      for cluster in token._.coref_clusters:
        print(token.text,"     |     ",cluster.main.text)
# Out:
# it      |      an input
# We      |      The other neural network, the “value network”
# it      |      AlphaGo
# we      |      The other neural network, the “value network”
# it      |      AlphaGo
# itself      |      AlphaGo
